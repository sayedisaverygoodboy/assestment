# %% [markdown]
# # Assement

# %% [markdown]
# Assignment Summary (Apex-Level Clarity)
# You must build a full evaluation framework for your existing RAG prototype using a corpus of Dr. Ambedkar’s documents and a 25-question test dataset. The goal is to measure the system's retrieval accuracy, answer quality, and semantic correctness, then compare different chunking strategies to determine the optimal configuration.
# Your responsibilities include:
#
#
# Implement 8 evaluation metrics across three dimensions:
#
# Retrieval: Hit Rate, MRR, Precision@K
# Answer Quality: Relevance, Faithfulness, ROUGE-L
# Semantic: Cosine Similarity, BLEU
# Evaluate three chunking strategies (200–300, 500–600, 800–1000 characters) and compare their impact on retrieval and answer quality.
#
# Perform performance analysis over all 25 Q&A pairs: Retrieval accuracy Answer quality trends vs. chunk size Failure mode identification Recommend the best configuration
#
#  Deliverables you must provide: evaluation.py (main evaluation logic) test_results.json (all metric scores) corpus/ (6 PDF/text docs) test_dataset.json results_analysis.md (your findings + recommendations) Updated requirements.txt Updated README.md (how to run evaluation) Tech stack: LangChain, ChromaDB, HuggingFace MiniLM embeddings, Ollama (Mistral-7B), ragas, rouge-score, nltk, scikit-learn.

# %%
import os

# %%
print(os.listdir())
# Out:
# ['.config', 'sample_data']
